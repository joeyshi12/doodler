# %%
from PIL import Image, ImageDraw, ImageFont

# %%
img = Image.open("images/goku.png")
draw = ImageDraw.Draw(img)

font = ImageFont.truetype("/usr/share/fonts/SauceCodePro/Sauce Code Pro Black Nerd Font Complete.ttf", 50)
text = "Peter Sux"
draw.text((5, 5), text, font=font, align="left", fill="black")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2557x1438 at 0x7F15CCE27B20>
